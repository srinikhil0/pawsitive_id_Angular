# %% [markdown]
# # Step 1 training model

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
from tensorflow.keras.applications import EfficientNetB0,EfficientNetB2, EfficientNetB3, EfficientNetB4, EfficientNetB5, EfficientNetB6
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
    print("Device:", tpu.master())
    strategy = tf.distribute.TPUStrategy(tpu)
except ValueError:
    print("Not connected to a TPU runtime. Using CPU/GPU strategy")
    strategy = tf.distribute.MirroredStrategy()
# Out:
# Not connected to a TPU runtime. Using CPU/GPU strategy

# %%
IMG_SIZE = 224

batch_size = 64

dataset_name = "stanford_dogs"

(ds_train, ds_test), ds_info = tfds.load(
    dataset_name, split=["train", "test"], with_info=True, as_supervised=True
)
NUM_CLASSES = ds_info.features["label"].num_classes
# Out:
# Downloading and preparing dataset 778.12 MiB (download: 778.12 MiB, generated: Unknown size, total: 778.12 MiB) to /root/tensorflow_datasets/stanford_dogs/0.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/12000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/stanford_dogs/0.2.0.incomplete4KPLX2/stanford_dogs-train.tfrecord*...:   0…
# Generating test examples...:   0%|          | 0/8580 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/stanford_dogs/0.2.0.incomplete4KPLX2/stanford_dogs-test.tfrecord*...:   0%…
# Dataset stanford_dogs downloaded and prepared to /root/tensorflow_datasets/stanford_dogs/0.2.0. Subsequent calls will reuse this data.

# %%
img_augmentation = Sequential(
    [
        layers.RandomRotation(factor=0.15),
        layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
        layers.RandomFlip(),
        layers.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %%
size = (IMG_SIZE, IMG_SIZE)
ds_train = ds_train.map(lambda image, label: (tf.image.resize(image, size), label))
ds_test = ds_test.map(lambda image, label: (tf.image.resize(image, size), label))

# %%
# One-hot / categorical encoding
def input_preprocess(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label


ds_train = ds_train.map(
    input_preprocess, num_parallel_calls=tf.data.AUTOTUNE
)
ds_train = ds_train.batch(batch_size=batch_size, drop_remainder=True)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

ds_test = ds_test.map(input_preprocess)
ds_test = ds_test.batch(batch_size=batch_size, drop_remainder=True)

# %%
ds_test.filter
# Out:
# <bound method DatasetV2.filter of <_BatchDataset element_spec=(TensorSpec(shape=(64, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(64, 120), dtype=tf.float32, name=None))>>

# %%
import os
def build_model(num_classes):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = img_augmentation(inputs)
    model = EfficientNetB3(include_top=False, input_tensor=x, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax", name="pred")(x)

    # checkpoint_path = "/Users/wangshiyu/Desktop/CS 673/Term Project/cp.ckpt"
    # checkpoint_dir = os.path.dirname(checkpoint_path)

    # Create a callback that saves the model's weights
    # cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                    # save_weights_only=True,
                                                    # verbose=1)
    # Compile

    model = tf.keras.Model(inputs, outputs, name="EfficientNet")
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
with strategy.scope():
    model = build_model(num_classes=NUM_CLASSES)

epochs = 50
# hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2)
# plot_hist(hist)
checkpoint_path = "/content/checkpoints"  # 模型保存路径
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, save_best_only=True, save_weights_only=True, monitor="val_accuracy", mode="max", verbose=1)
early_stopping = tf.keras.callbacks.EarlyStopping(patience=100, monitor="val_accuracy", mode="max", restore_best_weights=True, verbose=1)

model.fit(ds_train, epochs=epochs, validation_data=ds_test, callbacks=[model_checkpoint, early_stopping], verbose=2)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 0s 0us/step
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.83092, saving model to /content/checkpoints
# 187/187 - 91s - loss: 1.7889 - accuracy: 0.7404 - val_loss: 0.7083 - val_accuracy: 0.8309 - 91s/epoch - 488ms/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.83092 to 0.84387, saving model to /content/checkpoints
# 187/187 - 68s - loss: 0.6423 - accuracy: 0.8745 - val_loss: 0.8825 - val_accuracy: 0.8439 - 68s/epoch - 363ms/step
# Epoch 3/50
#
# Epoch 3: val_accuracy did not improve from 0.84387
# 187/187 - 66s - loss: 0.4242 - accuracy: 0.9026 - val_loss: 1.0351 - val_accuracy: 0.8390 - 66s/epoch - 354ms/step
# Epoch 4/50
#
# Epoch 4: val_accuracy did not improve from 0.84387
# 187/187 - 66s - loss: 0.3401 - accuracy: 0.9180 - val_loss: 1.1398 - val_accuracy: 0.8347 - 66s/epoch - 354ms/step
# Epoch 5/50
#
# Epoch 5: val_accuracy did not improve from 0.84387
# 187/187 - 66s - loss: 0.3151 - accuracy: 0.9222 - val_loss: 1.0746 - val_accuracy: 0.8365 - 66s/epoch - 355ms/step
# Epoch 6/50
#
# Epoch 6: val_accuracy improved from 0.84387 to 0.85063, saving model to /content/checkpoints
# 187/187 - 68s - loss: 0.2966 - accuracy: 0.9292 - val_loss: 0.9997 - val_accuracy: 0.8506 - 68s/epoch - 361ms/step
# Epoch 7/50
#
# Epoch 7: val_accuracy did not improve from 0.85063
# 187/187 - 66s - loss: 0.2546 - accuracy: 0.9364 - val_loss: 1.0706 - val_accuracy: 0.8434 - 66s/epoch - 355ms/step
# Epoch 8/50
#
# Epoch 8: val_accuracy improved from 0.85063 to 0.85145, saving model to /content/checkpoints
# 187/187 - 68s - loss: 0.2573 - accuracy: 0.9405 - val_loss: 1.0543 - val_accuracy: 0.8514 - 68s/epoch - 362ms/step
# Epoch 9/50
#
# Epoch 9: val_accuracy did not improve from 0.85145
# 187/187 - 66s - loss: 0.2498 - accuracy: 0.9427 - val_loss: 1.1597 - val_accuracy: 0.8446 - 66s/epoch - 354ms/step
# Epoch 10/50
#
# Epoch 10: val_accuracy did not improve from 0.85145
# 187/187 - 66s - loss: 0.2479 - accuracy: 0.9403 - val_loss: 1.1687 - val_accuracy: 0.8502 - 66s/epoch - 354ms/step
# Epoch 11/50
#
# Epoch 11: val_accuracy improved from 0.85145 to 0.85634, saving model to /content/checkpoints
# 187/187 - 67s - loss: 0.2399 - accuracy: 0.9438 - val_loss: 1.1921 - val_accuracy: 0.8563 - 67s/epoch - 361ms/step
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.2395 - accuracy: 0.9464 - val_loss: 1.2444 - val_accuracy: 0.8496 - 66s/epoch - 354ms/step
# Epoch 13/50
#
# Epoch 13: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.3063 - accuracy: 0.9382 - val_loss: 1.3578 - val_accuracy: 0.8438 - 66s/epoch - 354ms/step
# Epoch 14/50
#
# Epoch 14: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.2954 - accuracy: 0.9418 - val_loss: 1.4682 - val_accuracy: 0.8446 - 66s/epoch - 354ms/step
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.2881 - accuracy: 0.9415 - val_loss: 1.4875 - val_accuracy: 0.8490 - 66s/epoch - 354ms/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.3126 - accuracy: 0.9423 - val_loss: 1.5132 - val_accuracy: 0.8478 - 66s/epoch - 354ms/step
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.2779 - accuracy: 0.9459 - val_loss: 1.4999 - val_accuracy: 0.8524 - 66s/epoch - 354ms/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.3147 - accuracy: 0.9430 - val_loss: 1.6834 - val_accuracy: 0.8489 - 66s/epoch - 354ms/step
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.3261 - accuracy: 0.9479 - val_loss: 1.7839 - val_accuracy: 0.8464 - 66s/epoch - 354ms/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.3219 - accuracy: 0.9498 - val_loss: 1.7671 - val_accuracy: 0.8527 - 66s/epoch - 354ms/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.2888 - accuracy: 0.9510 - val_loss: 1.9379 - val_accuracy: 0.8431 - 66s/epoch - 354ms/step
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.3509 - accuracy: 0.9469 - val_loss: 1.8487 - val_accuracy: 0.8561 - 66s/epoch - 353ms/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.2957 - accuracy: 0.9539 - val_loss: 1.9098 - val_accuracy: 0.8503 - 66s/epoch - 354ms/step
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.2881 - accuracy: 0.9552 - val_loss: 1.9442 - val_accuracy: 0.8514 - 66s/epoch - 354ms/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.3158 - accuracy: 0.9540 - val_loss: 2.0103 - val_accuracy: 0.8489 - 66s/epoch - 355ms/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.3143 - accuracy: 0.9540 - val_loss: 2.2240 - val_accuracy: 0.8462 - 66s/epoch - 355ms/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.3092 - accuracy: 0.9569 - val_loss: 2.1473 - val_accuracy: 0.8512 - 66s/epoch - 354ms/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.85634
# 187/187 - 66s - loss: 0.3314 - accuracy: 0.9535 - val_loss: 2.2360 - val_accuracy: 0.8532 - 66s/epoch - 354ms/step
# Epoch 29/50
#
# Epoch 29: val_accuracy improved from 0.85634 to 0.85728, saving model to /content/checkpoints
# 187/187 - 68s - loss: 0.3488 - accuracy: 0.9536 - val_loss: 2.2050 - val_accuracy: 0.8573 - 68s/epoch - 362ms/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.85728
# 187/187 - 66s - loss: 0.2802 - accuracy: 0.9601 - val_loss: 2.2579 - val_accuracy: 0.8561 - 66s/epoch - 355ms/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.85728
# 187/187 - 66s - loss: 0.3312 - accuracy: 0.9568 - val_loss: 2.3653 - val_accuracy: 0.8566 - 66s/epoch - 354ms/step
# Epoch 32/50
#
# Epoch 32: val_accuracy did not improve from 0.85728
# 187/187 - 66s - loss: 0.3254 - accuracy: 0.9591 - val_loss: 2.4979 - val_accuracy: 0.8503 - 66s/epoch - 354ms/step
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.85728
# 187/187 - 66s - loss: 0.2980 - accuracy: 0.9618 - val_loss: 2.4426 - val_accuracy: 0.8554 - 66s/epoch - 354ms/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.85728
# 187/187 - 66s - loss: 0.3071 - accuracy: 0.9606 - val_loss: 2.6601 - val_accuracy: 0.8523 - 66s/epoch - 354ms/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.85728
# 187/187 - 66s - loss: 0.3787 - accuracy: 0.9581 - val_loss: 2.7240 - val_accuracy: 0.8510 - 66s/epoch - 354ms/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.85728
# 187/187 - 66s - loss: 0.3699 - accuracy: 0.9555 - val_loss: 2.6629 - val_accuracy: 0.8530 - 66s/epoch - 354ms/step
# Epoch 37/50
#
# Epoch 37: val_accuracy improved from 0.85728 to 0.85809, saving model to /content/checkpoints
# 187/187 - 68s - loss: 0.3290 - accuracy: 0.9654 - val_loss: 2.7047 - val_accuracy: 0.8581 - 68s/epoch - 362ms/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.85809
# 187/187 - 66s - loss: 0.3140 - accuracy: 0.9629 - val_loss: 2.8489 - val_accuracy: 0.8532 - 66s/epoch - 355ms/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.85809
# 187/187 - 66s - loss: 0.3693 - accuracy: 0.9622 - val_loss: 2.8427 - val_accuracy: 0.8573 - 66s/epoch - 354ms/step
# Epoch 40/50
#
# Epoch 40: val_accuracy improved from 0.85809 to 0.86019, saving model to /content/checkpoints
# 187/187 - 68s - loss: 0.3464 - accuracy: 0.9624 - val_loss: 2.9317 - val_accuracy: 0.8602 - 68s/epoch - 361ms/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.86019
# 187/187 - 66s - loss: 0.3175 - accuracy: 0.9648 - val_loss: 2.9854 - val_accuracy: 0.8544 - 66s/epoch - 355ms/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.86019
# 187/187 - 66s - loss: 0.2784 - accuracy: 0.9688 - val_loss: 2.9452 - val_accuracy: 0.8598 - 66s/epoch - 353ms/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.86019
# 187/187 - 66s - loss: 0.3430 - accuracy: 0.9659 - val_loss: 2.9824 - val_accuracy: 0.8598 - 66s/epoch - 353ms/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.86019
# 187/187 - 66s - loss: 0.3190 - accuracy: 0.9683 - val_loss: 3.2030 - val_accuracy: 0.8579 - 66s/epoch - 354ms/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.86019
# 187/187 - 66s - loss: 0.3673 - accuracy: 0.9652 - val_loss: 3.3211 - val_accuracy: 0.8561 - 66s/epoch - 355ms/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.86019
# 187/187 - 66s - loss: 0.3380 - accuracy: 0.9657 - val_loss: 3.3571 - val_accuracy: 0.8561 - 66s/epoch - 354ms/step
# Epoch 47/50
#
# Epoch 47: val_accuracy improved from 0.86019 to 0.86264, saving model to /content/checkpoints
# 187/187 - 68s - loss: 0.3851 - accuracy: 0.9639 - val_loss: 3.2868 - val_accuracy: 0.8626 - 68s/epoch - 361ms/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.86264
# 187/187 - 66s - loss: 0.3172 - accuracy: 0.9700 - val_loss: 3.6348 - val_accuracy: 0.8489 - 66s/epoch - 354ms/step
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 0.86264
# 187/187 - 66s - loss: 0.3413 - accuracy: 0.9680 - val_loss: 3.4712 - val_accuracy: 0.8551 - 66s/epoch - 355ms/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.86264
# 187/187 - 66s - loss: 0.3136 - accuracy: 0.9715 - val_loss: 3.6776 - val_accuracy: 0.8594 - 66s/epoch - 354ms/step

# %%
model.input_shape
# Out:
# (None, 224, 224, 3)

# %%
import tensorflow as tf


# save the model as SavedModel format
# tf.saved_model.save(model, '/content/efficentNetSavedModel')
# model.save('/content/efficientNet.h5')
model.save_weights('/content/model_weights.h5')

# %% [markdown]
# # Step 2 transfer TF model to onnx formate

# %%
! pip install onnxruntime
! pip install tf2onnx
# Out:
# Collecting onnxruntime
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 49.5 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (23.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (1.11.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime) (1.3.0)
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.15.1
# Collecting tf2onnx
#   Downloading tf2onnx-1.14.0-py3-none-any.whl (451 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.2/451.2 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.22.4)
# Collecting onnx>=1.4.1 (from tf2onnx)
#   Downloading onnx-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 98.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf2onnx) (1.16.0)
# Collecting flatbuffers<3.0,>=1.12 (from tf2onnx)
#   Downloading flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.4.1->tf2onnx) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.4.1->tf2onnx) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tf2onnx) (3.4)
# Installing collected packages: flatbuffers, onnx, tf2onnx
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.5.26
#     Uninstalling flatbuffers-23.5.26:
#       Successfully uninstalled flatbuffers-23.5.26
# Successfully installed flatbuffers-2.0.7 onnx-1.14.0 tf2onnx-1.14.0

# %%
import tensorflow as tf
import tf2onnx
from tf2onnx.convert import from_keras
import onnx
# from tf2onnx.optimizer import optimize_graph
input_signature = [tf.TensorSpec([None, 224,224,3], tf.float32, name='x')]
onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature, opset=13)
onnx.save(onnx_model, "/content/efficientNetB3.onnx")

# %%
import onnx

def check_onnx_model(filename):
    try:
        onnx_model = onnx.load(filename)
        onnx.checker.check_model(onnx_model)
        print("onnxfile works.")
    except onnx.onnx_cpp2py_export.checker.ValidationError as e:
        print("onnxfile cannot work")
        print(e)

check_onnx_model("/content/efficientNetB3.onnx")

# %% [markdown]
# # Step3 Test onnx

# %%
import numpy as np
import onnxruntime as rt
from PIL import Image

# load onnx model
model_path = "/content/efficientNetB3.onnx"
session = rt.InferenceSession(model_path)

# preprocess the image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))
    image_array = np.array(image.convert("RGB"))
    image_array = np.expand_dims(image_array, axis=0)
    image_array = image_array.astype(np.float32)
    return image_array

# prepare input data
input_name = session.get_inputs()[0].name
image_path = "/content/appenzeller.jpeg"
input_data = preprocess_image(image_path)

# get inference
outputs = session.run(None, {input_name: input_data})

# deal with the output
output_data = outputs[0]
output_data = np.squeeze(output_data)

# %%
# get the label index
predicted_class_index = np.argmax(output_data)
print("Predicted class index:", predicted_class_index)

# get the label name
class_labels = ds_info.features["label"].names  # 替换为你的类别标签
predicted_class_label = class_labels[predicted_class_index]
print("Predicted class label:", predicted_class_label)
# Out:
# Predicted class index: 89
# Predicted class label: n02107908-appenzeller

# %%
ds_info.features["label"].names
# Out:
# ['n02085620-chihuahua',
#  'n02085782-japanese_spaniel',
#  'n02085936-maltese_dog',
#  'n02086079-pekinese',
#  'n02086240-shih-tzu',
#  'n02086646-blenheim_spaniel',
#  'n02086910-papillon',
#  'n02087046-toy_terrier',
#  'n02087394-rhodesian_ridgeback',
#  'n02088094-afghan_hound',
#  'n02088238-basset',
#  'n02088364-beagle',
#  'n02088466-bloodhound',
#  'n02088632-bluetick',
#  'n02089078-black-and-tan_coonhound',
#  'n02089867-walker_hound',
#  'n02089973-english_foxhound',
#  'n02090379-redbone',
#  'n02090622-borzoi',
#  'n02090721-irish_wolfhound',
#  'n02091032-italian_greyhound',
#  'n02091134-whippet',
#  'n02091244-ibizan_hound',
#  'n02091467-norwegian_elkhound',
#  'n02091635-otterhound',
#  'n02091831-saluki',
#  'n02092002-scottish_deerhound',
#  'n02092339-weimaraner',
#  'n02093256-staffordshire_bullterrier',
#  'n02093428-american_staffordshire_terrier',
#  'n02093647-bedlington_terrier',
#  'n02093754-border_terrier',
#  'n02093859-kerry_blue_terrier',
#  'n02093991-irish_terrier',
#  'n02094114-norfolk_terrier',
#  'n02094258-norwich_terrier',
#  'n02094433-yorkshire_terrier',
#  'n02095314-wire-haired_fox_terrier',
#  'n02095570-lakeland_terrier',
#  'n02095889-sealyham_terrier',
#  'n02096051-airedale',
#  'n02096177-cairn',
#  'n02096294-australian_terrier',
#  'n02096437-dandie_dinmont',
#  'n02096585-boston_bull',
#  'n02097047-miniature_schnauzer',
#  'n02097130-giant_schnauzer',
#  'n02097209-standard_schnauzer',
#  'n02097298-scotch_terrier',
#  'n02097474-tibetan_terrier',
#  'n02097658-silky_terrier',
#  'n02098105-soft-coated_wheaten_terrier',
#  'n02098286-west_highland_white_terrier',
#  'n02098413-lhasa',
#  'n02099267-flat-coated_retriever',
#  'n02099429-curly-coated_retriever',
#  'n02099601-golden_retriever',
#  'n02099712-labrador_retriever',
#  'n02099849-chesapeake_bay_retriever',
#  'n02100236-german_short-haired_pointer',
#  'n02100583-vizsla',
#  'n02100735-english_setter',
#  'n02100877-irish_setter',
#  'n02101006-gordon_setter',
#  'n02101388-brittany_spaniel',
#  'n02101556-clumber',
#  'n02102040-english_springer',
#  'n02102177-welsh_springer_spaniel',
#  'n02102318-cocker_spaniel',
#  'n02102480-sussex_spaniel',
#  'n02102973-irish_water_spaniel',
#  'n02104029-kuvasz',
#  'n02104365-schipperke',
#  'n02105056-groenendael',
#  'n02105162-malinois',
#  'n02105251-briard',
#  'n02105412-kelpie',
#  'n02105505-komondor',
#  'n02105641-old_english_sheepdog',
#  'n02105855-shetland_sheepdog',
#  'n02106030-collie',
#  'n02106166-border_collie',
#  'n02106382-bouvier_des_flandres',
#  'n02106550-rottweiler',
#  'n02106662-german_shepherd',
#  'n02107142-doberman',
#  'n02107312-miniature_pinscher',
#  'n02107574-greater_swiss_mountain_dog',
#  'n02107683-bernese_mountain_dog',
#  'n02107908-appenzeller',
#  'n02108000-entlebucher',
#  'n02108089-boxer',
#  'n02108422-bull_mastiff',
#  'n02108551-tibetan_mastiff',
#  'n02108915-french_bulldog',
#  'n02109047-great_dane',
#  'n02109525-saint_bernard',
#  'n02109961-eskimo_dog',
#  'n02110063-malamute',
#  'n02110185-siberian_husky',
#  'n02110627-affenpinscher',
#  'n02110806-basenji',
#  'n02110958-pug',
#  'n02111129-leonberg',
#  'n02111277-newfoundland',
#  'n02111500-great_pyrenees',
#  'n02111889-samoyed',
#  'n02112018-pomeranian',
#  'n02112137-chow',
#  'n02112350-keeshond',
#  'n02112706-brabancon_griffon',
#  'n02113023-pembroke',
#  'n02113186-cardigan',
#  'n02113624-toy_poodle',
#  'n02113712-miniature_poodle',
#  'n02113799-standard_poodle',
#  'n02113978-mexican_hairless',
#  'n02115641-dingo',
#  'n02115913-dhole',
#  'n02116738-african_hunting_dog']
